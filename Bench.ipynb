# %% [markdown]
# ## Benchamrks against BLAS

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./bench.csv", sep = ";")

# %%
data.head()
# Out:
#    size   matrice      blas
# 0    32  0.000018  0.000377
# 1    64  0.000085  0.000026
# 2   128  0.000493  0.038167
# 3   256  0.038520  0.001818
# 4   512  0.136679  0.045951

# %% [markdown]
# ## Plots

# %%
data["matrice"]
# Out:
# 0    0.000018
# 1    0.000085
# 2    0.000493
# 3    0.038520
# 4    0.136679
# 5    1.578344
# 6    3.873177
# Name: matrice, dtype: float64

# %%
plt.plot(data["size"], data["matrice"], color = "black", label = "matrice")
plt.plot(data["size"], data["blas"], color = "red", label = "blas")
plt.legend()
plt.show()
